# %% [markdown]
# <a href="https://colab.research.google.com/github/fruct49/University/blob/main/Practice/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B0%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0_%E2%84%962_%D0%9F%D0%B0%D1%80%D0%B0%D0%B4%D0%BE%D0%BA%D1%81_%D0%B4%D0%BD%D0%B5%D0%B9_%D1%80%D0%BE%D0%B6%D0%B4%D0%B5%D0%BD%D0%B8%D1%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Практическая работа №2. Парадокс дней рождения
#
# Парадокс дней рождения - это интересное явление в теории вероятностей, которое часто удивляет людей своим неожиданным результатом.
#
# **Суть парадокса:**
# - В группе из 23 или более человек вероятность того, что у хотя бы двух людей совпадут дни рождения, превышает 50%.
# - При увеличении группы до 60 человек эта вероятность возрастает до более чем 99%.

# %% [markdown]
# **Почему это кажется парадоксальным:**
# Многие люди интуитивно полагают, что для такой высокой вероятности совпадения нужно гораздо больше людей. Это связано с тем, что мы часто неправильно оцениваем количество возможных пар в группе.
#
# **Объяснение:**
# - В группе из 23 человек можно составить 253 уникальные пары.
# - Каждая пара имеет шанс на совпадение дней рождения.
# - Большое количество возможных пар значительно увеличивает вероятность хотя бы одного совпадения.

# %% [markdown]
# #### **Задание**

# %% [markdown]
# - Напишите программу, которая симулирует парадокс дней рождения и проверяет его достоверность.
#
# - **Упрощение:** Для удобства расчетов считайте, что в каждом месяце 28 дней (всего 336 возможных дней рождения в году).
#
# - **Требования к программе:**
#
#   1. Создайте функцию `birthday(iterations, people=23)`, которая:
#     - Принимает параметр `iterations` - количество повторений эксперимента.
#     - Принимает параметр `people` - количество человек в группе (по умолчанию 23).
#     - Проводит указанное количество симуляций для группы из `people` человек.
#     - Возвращает **процент случаев**, когда было обнаружено совпадение дней рождения, в виде числа с плавающей точкой.
#
#   2. Алгоритм работы функции:
#     - Генерируйте случайные дни рождения для заданного количества людей.
#     - Проверяйте, есть ли совпадения дней рождения в этой группе.
#     - Повторите этот процесс указанное количество раз (`iterations`).
#     - Подсчитайте процент случаев, когда были обнаружены совпадения.
#
#   3. В основной части программы:
#     - Используйте функцию `birthday()` для проверки вероятности совпадений для групп разного размера (например, от 10 до 60 человек).
#     - Выведите результаты, показывающие, как изменяется вероятность совпадения с увеличением размера группы.
#
# **Пример использования:**
#
# ```python
# result_23 = birthday(10000, 23)
# print(f"Вероятность совпадения дней рождения в группе из 23 человек: {result_23:.2f}%")
#
# result_60 = birthday(10000, 60)
# print(f"Вероятность совпадения дней рождения в группе из 60 человек: {result_60:.2f}%")
# ```

# %%
import random
def birthday(iterations, people=23):
    matches = 0
    for i in range(iterations):
        birthdays = [random.randint(1, 336) for g in range(people)]
        if len(birthdays) != len(set(birthdays)):
            matches += 1
    probability = (matches / iterations) * 100
    return probability
for group_size in range(10, 61):
    result = birthday(10000, group_size)
    print(f"Вероятность совпадения дней рождения в группе из {group_size} человек: {result:.2f}%")
# Out:
# Вероятность совпадения дней рождения в группе из 10 человек: 12.76%
# Вероятность совпадения дней рождения в группе из 11 человек: 15.08%
# Вероятность совпадения дней рождения в группе из 12 человек: 17.88%
# Вероятность совпадения дней рождения в группе из 13 человек: 21.83%
# Вероятность совпадения дней рождения в группе из 14 человек: 23.70%
# Вероятность совпадения дней рождения в группе из 15 человек: 27.35%
# Вероятность совпадения дней рождения в группе из 16 человек: 30.33%
# Вероятность совпадения дней рождения в группе из 17 человек: 33.74%
# Вероятность совпадения дней рождения в группе из 18 человек: 36.57%
# Вероятность совпадения дней рождения в группе из 19 человек: 40.58%
# Вероятность совпадения дней рождения в группе из 20 человек: 43.55%
# Вероятность совпадения дней рождения в группе из 21 человек: 46.88%
# Вероятность совпадения дней рождения в группе из 22 человек: 49.81%
# Вероятность совпадения дней рождения в группе из 23 человек: 53.47%
# Вероятность совпадения дней рождения в группе из 24 человек: 56.30%
# Вероятность совпадения дней рождения в группе из 25 человек: 60.06%
# Вероятность совпадения дней рождения в группе из 26 человек: 63.46%
# Вероятность совпадения дней рождения в группе из 27 человек: 65.79%
# Вероятность совпадения дней рождения в группе из 28 человек: 68.60%
# Вероятность совпадения дней рождения в группе из 29 человек: 70.81%
# Вероятность совпадения дней рождения в группе из 30 человек: 73.37%
# Вероятность совпадения дней рождения в группе из 31 человек: 76.54%
# Вероятность совпадения дней рождения в группе из 32 человек: 78.28%
# Вероятность совпадения дней рождения в группе из 33 человек: 80.01%
# Вероятность совпадения дней рождения в группе из 34 человек: 82.70%
# Вероятность совпадения дней рождения в группе из 35 человек: 84.13%
# Вероятность совпадения дней рождения в группе из 36 человек: 85.85%
# Вероятность совпадения дней рождения в группе из 37 человек: 87.84%
# Вероятность совпадения дней рождения в группе из 38 человек: 87.92%
# Вероятность совпадения дней рождения в группе из 39 человек: 89.69%
# Вероятность совпадения дней рождения в группе из 40 человек: 91.04%
# Вероятность совпадения дней рождения в группе из 41 человек: 92.06%
# Вероятность совпадения дней рождения в группе из 42 человек: 93.41%
# Вероятность совпадения дней рождения в группе из 43 человек: 93.75%
# Вероятность совпадения дней рождения в группе из 44 человек: 94.78%
# Вероятность совпадения дней рождения в группе из 45 человек: 95.59%
# Вероятность совпадения дней рождения в группе из 46 человек: 95.98%
# Вероятность совпадения дней рождения в группе из 47 человек: 96.41%
# Вероятность совпадения дней рождения в группе из 48 человек: 96.95%
# Вероятность совпадения дней рождения в группе из 49 человек: 97.72%
# Вероятность совпадения дней рождения в группе из 50 человек: 97.75%
# Вероятность совпадения дней рождения в группе из 51 человек: 98.04%
# Вероятность совпадения дней рождения в группе из 52 человек: 98.47%
# Вероятность совпадения дней рождения в группе из 53 человек: 98.55%
# Вероятность совпадения дней рождения в группе из 54 человек: 99.04%
# Вероятность совпадения дней рождения в группе из 55 человек: 98.95%
# Вероятность совпадения дней рождения в группе из 56 человек: 99.32%
# Вероятность совпадения дней рождения в группе из 57 человек: 99.32%
# Вероятность совпадения дней рождения в группе из 58 человек: 99.43%
# Вероятность совпадения дней рождения в группе из 59 человек: 99.58%
# Вероятность совпадения дней рождения в группе из 60 человек: 99.60%
